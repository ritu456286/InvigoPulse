# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv("./SalesFINAL12312016.csv")
df.head()
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice SalesDate  Volume  Classification  \
# 0              1         16.49       16.49  1/1/2016     750               1
# 1              2         32.98       16.49  1/2/2016     750               1
# 2              1         16.49       16.49  1/3/2016     750               1
# 3              1         14.49       14.49  1/8/2016     750               1
# 4              2         69.98       34.99  1/9/2016     375               1
#
#    ExciseTax  VendorNo                   VendorName
# 0       0.79     12546  JIM BEAM BRANDS COMPANY
# 1       1.57     12546  JIM BEAM BRANDS COMPANY
# 2       0.79     12546  JIM BEAM BRANDS COMPANY
# 3       0.79     12546  JIM BEAM BRANDS COMPANY
# 4       0.79     12546  JIM BEAM BRANDS COMPANY

# %%
#Determine the size of the dataframe
df.shape
# Out:
# (1048575, 14)

# %% [markdown]
# This implies we have 1,048,575 (near a million) rows and 14 columns(features) in our dataframe.

# %% [markdown]
# To perform **Demand Forecasting**, we will take a random sample from the dataframe, of the size = 40,000

# %%
df = df.sample(n = 40000)

# %% [markdown]
# ## DATA ANALYSIS

# %%
print("\nSales Columns:")
print(df.columns.tolist())
# Out:
# Sales Columns:
# ['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity', 'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification', 'ExciseTax', 'VendorNo', 'VendorName']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40000 entries, 280017 to 6999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   InventoryId     40000 non-null  object
#  1   Store           40000 non-null  int64
#  2   Brand           40000 non-null  int64
#  3   Description     40000 non-null  object
#  4   Size            40000 non-null  object
#  5   SalesQuantity   40000 non-null  int64
#  6   SalesDollars    40000 non-null  float64
#  7   SalesPrice      40000 non-null  float64
#  8   SalesDate       40000 non-null  object
#  9   Volume          40000 non-null  int64
#  10  Classification  40000 non-null  int64
#  11  ExciseTax       40000 non-null  float64
#  12  VendorNo        40000 non-null  int64
#  13  VendorName      40000 non-null  object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 4.6+ MB

# %%
df.dtypes
# Out:
# InventoryId        object
# Store               int64
# Brand               int64
# Description        object
# Size               object
# SalesQuantity       int64
# SalesDollars      float64
# SalesPrice        float64
# SalesDate          object
# Volume              int64
# Classification      int64
# ExciseTax         float64
# VendorNo            int64
# VendorName         object
# dtype: object

# %% [markdown]
# **Observation**: We observe that, the SalesDate feature is of type "object". We need SalesDate later, to predict the SalesQuantity, so we need to handle it's data type.

# %%
df.describe()
# Out:
#               Store         Brand  SalesQuantity  SalesDollars    SalesPrice  \
# count  40000.000000  40000.000000   40000.000000  40000.000000  40000.000000
# mean      40.261975  12173.010725       2.322850     31.560647     15.441432
# std       24.392342  12452.446682       3.539171     89.768378     12.906787
# min        1.000000     58.000000       1.000000      0.990000      0.990000
# 25%       16.000000   3662.000000       1.000000     10.990000      8.990000
# 50%       39.000000   6281.000000       1.000000     17.990000     12.990000
# 75%       64.000000  17981.000000       2.000000     31.990000     18.990000
# max       79.000000  90089.000000     253.000000  13279.970000    449.990000
#
#              Volume  Classification     ExciseTax      VendorNo
# count  40000.000000    40000.000000  40000.000000  40000.000000
# mean     946.236450        1.413350      1.311487   7021.525500
# std      709.150813        0.492441      3.044562   8461.482082
# min       50.000000        1.000000      0.010000    105.000000
# 25%      750.000000        1.000000      0.160000   3252.000000
# 50%      750.000000        1.000000      0.680000   4425.000000
# 75%     1000.000000        2.000000      1.570000   9552.000000
# max    18000.000000        2.000000    132.300000  98450.000000

# %% [markdown]
# **Observation**: We observe that, our minimum sales was 1.0 and maximum goes upto 108.0, This huge deviation will also affect our predictions. We will handle these extreme values(*Outliers*) too, later in this notebook.

# %%
df.isnull().sum()
# Out:
# InventoryId       0
# Store             0
# Brand             0
# Description       0
# Size              0
# SalesQuantity     0
# SalesDollars      0
# SalesPrice        0
# SalesDate         0
# Volume            0
# Classification    0
# ExciseTax         0
# VendorNo          0
# VendorName        0
# dtype: int64

# %% [markdown]
# **Observation**: We don't have any null values in our DataFrame. So far good to GO!

# %%
df.Description.value_counts()
# Out:
# Description
# Smirnoff 80 Proof               283
# Jim Beam                        268
# Capt Morgan Spiced Rum          264
# Jagermeister Liqueur            259
# Jack Daniels No 7 Black         253
#                                ...
# Zonin Prosecco Brut               1
# Ch de Pierreux Brouilly Rsv       1
# Kendall Jackson Vt RSV Syrah      1
# Corazon de Agave Blanco           1
# Double Canyon Heaven H Cab S      1
# Name: count, Length: 3892, dtype: int64

# %% [markdown]
# **Observation**: In our dataframe, for some brands, we've enough number of rows to predict their sales, but for some brands we only have one row, which may impact our predictions.

# %% [markdown]
# ## DATA PREPROCESSING

# %%
df['VendorName'] = df['VendorName'].str.strip()
df['Description'] = df['Description'].str.strip()

# %% [markdown]
# Convert the SalesDate to Date time Object

# %%
df['SalesDate'] = pd.to_datetime(df['SalesDate'])

# %%
df.dtypes
# Out:
# InventoryId               object
# Store                      int64
# Brand                      int64
# Description               object
# Size                      object
# SalesQuantity              int64
# SalesDollars             float64
# SalesPrice               float64
# SalesDate         datetime64[ns]
# Volume                     int64
# Classification             int64
# ExciseTax                float64
# VendorNo                   int64
# VendorName                object
# dtype: object

# %% [markdown]
# Extract the year, month and day from the SalesDate

# %%
df['year'] = df['SalesDate'].dt.year
df['month'] = df['SalesDate'].dt.month
df['day'] = df['SalesDate'].dt.day

# %%
df
# Out:
#                  InventoryId  Store  Brand                   Description  \
# 280017    34_PITMERDEN_25339     34  25339    Le Haut Medoc de Lascombes
# 976274      11_CARDEND_26949     11  26949       Sonoma-Cutrer Chard RRV
# 59970     13_TARMSWORTH_5401     13   5401          Jagermeister Liqueur
# 815281    73_DONCASTER_36989     73  36989          Duck Pond Chard Wash
# 707907    67_EANVERNESS_8218     67   8218     Camarena Reposado Tequila
# ...                      ...    ...    ...                           ...
# 603811       60_IRRAGIN_5735     60   5735                    Malibu Rum
# 861252    76_DONCASTER_22566     76  22566   LaBelle Winery 2013 Dry Rsl
# 279641    34_PITMERDEN_24863     34  24863  Double Canyon Heaven H Cab S
# 591585      60_IRRAGIN_23870     60  23870   Col-di-Sasso Sangiovese/Cab
# 6999    1_HARDERSFIELD_32675      1  32675       Blackstone Cab Svgn Cal
#
#          Size  SalesQuantity  SalesDollars  SalesPrice  SalesDate  Volume  \
# 280017  750mL              1         34.99       34.99 2016-01-23     750
# 976274  750mL              2         45.98       22.99 2016-02-26     750
# 59970   200mL              1          5.99        5.99 2016-01-04     200
# 815281  750mL              1         13.99       13.99 2016-01-30     750
# 707907  1.75L              1         31.99       31.99 2016-01-09    1750
# ...       ...            ...           ...         ...        ...     ...
# 603811  750mL              1         12.99       12.99 2016-01-11     750
# 861252  750mL              1         13.99       13.99 2016-01-14     750
# 279641  750mL              2         47.98       23.99 2016-01-09     750
# 591585  750mL              1          8.99        8.99 2016-01-18     750
# 6999    750mL              1         10.99       10.99 2016-01-29     750
#
#         Classification  ExciseTax  VendorNo                 VendorName  year  \
# 280017               2       0.11      4425      MARTIGNETTI COMPANIES  2016
# 976274               2       0.22      1128          BROWN-FORMAN CORP  2016
# 59970                1       0.21      3089  SIDNEY FRANK IMPORTING CO  2016
# 815281               2       0.11     10754             PERFECTA WINES  2016
# 707907               1       1.84      3252         E & J GALLO WINERY  2016
# ...                ...        ...       ...                        ...   ...
# 603811               1       0.79     17035          PERNOD RICARD USA  2016
# 861252               2       0.11     90032    LABELLE VYDS AND WINERY  2016
# 279641               2       0.22      4425      MARTIGNETTI COMPANIES  2016
# 591585               2       0.11       516        BANFI PRODUCTS CORP  2016
# 6999                 2       0.11      1392   CONSTELLATION BRANDS INC  2016
#
#         month  day
# 280017      1   23
# 976274      2   26
# 59970       1    4
# 815281      1   30
# 707907      1    9
# ...       ...  ...
# 603811      1   11
# 861252      1   14
# 279641      1    9
# 591585      1   18
# 6999        1   29
#
# [40000 rows x 17 columns]

# %% [markdown]
# Drop the following Columns:
# 1) InventoryId; because each row has different ID
# 2) SalesDate; because we've already extracted the required info from this feature in year, month, and day columns.
# 3) Size; because it has some ambiguity in it.

# %%
df.drop(['InventoryId','SalesDate', 'Size'], inplace=True, axis=1)

# %%
df.head()
# Out:
#         Store  Brand                 Description  SalesQuantity  SalesDollars  \
# 280017     34  25339  Le Haut Medoc de Lascombes              1         34.99
# 976274     11  26949     Sonoma-Cutrer Chard RRV              2         45.98
# 59970      13   5401        Jagermeister Liqueur              1          5.99
# 815281     73  36989        Duck Pond Chard Wash              1         13.99
# 707907     67   8218   Camarena Reposado Tequila              1         31.99
#
#         SalesPrice  Volume  Classification  ExciseTax  VendorNo  \
# 280017       34.99     750               2       0.11      4425
# 976274       22.99     750               2       0.22      1128
# 59970         5.99     200               1       0.21      3089
# 815281       13.99     750               2       0.11     10754
# 707907       31.99    1750               1       1.84      3252
#
#                        VendorName  year  month  day
# 280017      MARTIGNETTI COMPANIES  2016      1   23
# 976274          BROWN-FORMAN CORP  2016      2   26
# 59970   SIDNEY FRANK IMPORTING CO  2016      1    4
# 815281             PERFECTA WINES  2016      1   30
# 707907         E & J GALLO WINERY  2016      1    9

# %% [markdown]
# ### Removing the Outliers

# %%
z_scores = (df[['SalesQuantity', 'SalesDollars', 'SalesPrice', 'Volume', 'ExciseTax']] - df[['SalesQuantity', 'SalesDollars', 'SalesPrice', 'Volume', 'ExciseTax']].mean()) / df[['SalesQuantity', 'SalesDollars', 'SalesPrice', 'Volume', 'ExciseTax']].std()
threshold = 3
outliers = df[(np.abs(z_scores) > threshold).any(axis=1)]
df_cleaned = df[(np.abs(z_scores) <= threshold).all(axis=1)]

# %%
df_cleaned
# Out:
#         Store  Brand                   Description  SalesQuantity  \
# 280017     34  25339    Le Haut Medoc de Lascombes              1
# 976274     11  26949       Sonoma-Cutrer Chard RRV              2
# 59970      13   5401          Jagermeister Liqueur              1
# 815281     73  36989          Duck Pond Chard Wash              1
# 707907     67   8218     Camarena Reposado Tequila              1
# ...       ...    ...                           ...            ...
# 603811     60   5735                    Malibu Rum              1
# 861252     76  22566   LaBelle Winery 2013 Dry Rsl              1
# 279641     34  24863  Double Canyon Heaven H Cab S              2
# 591585     60  23870   Col-di-Sasso Sangiovese/Cab              1
# 6999        1  32675       Blackstone Cab Svgn Cal              1
#
#         SalesDollars  SalesPrice  Volume  Classification  ExciseTax  VendorNo  \
# 280017         34.99       34.99     750               2       0.11      4425
# 976274         45.98       22.99     750               2       0.22      1128
# 59970           5.99        5.99     200               1       0.21      3089
# 815281         13.99       13.99     750               2       0.11     10754
# 707907         31.99       31.99    1750               1       1.84      3252
# ...              ...         ...     ...             ...        ...       ...
# 603811         12.99       12.99     750               1       0.79     17035
# 861252         13.99       13.99     750               2       0.11     90032
# 279641         47.98       23.99     750               2       0.22      4425
# 591585          8.99        8.99     750               2       0.11       516
# 6999           10.99       10.99     750               2       0.11      1392
#
#                        VendorName  year  month  day
# 280017      MARTIGNETTI COMPANIES  2016      1   23
# 976274          BROWN-FORMAN CORP  2016      2   26
# 59970   SIDNEY FRANK IMPORTING CO  2016      1    4
# 815281             PERFECTA WINES  2016      1   30
# 707907         E & J GALLO WINERY  2016      1    9
# ...                           ...   ...    ...  ...
# 603811          PERNOD RICARD USA  2016      1   11
# 861252    LABELLE VYDS AND WINERY  2016      1   14
# 279641      MARTIGNETTI COMPANIES  2016      1    9
# 591585        BANFI PRODUCTS CORP  2016      1   18
# 6999     CONSTELLATION BRANDS INC  2016      1   29
#
# [37698 rows x 14 columns]

# %%
df_cleaned.shape
# Out:
# (37698, 14)

# %% [markdown]
# **Observation** : Earlier we had 40,000 rows, after removing the outliers, we've 18,881 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40000 entries, 280017 to 6999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store           40000 non-null  int64
#  1   Brand           40000 non-null  int64
#  2   Description     40000 non-null  object
#  3   SalesQuantity   40000 non-null  int64
#  4   SalesDollars    40000 non-null  float64
#  5   SalesPrice      40000 non-null  float64
#  6   Volume          40000 non-null  int64
#  7   Classification  40000 non-null  int64
#  8   ExciseTax       40000 non-null  float64
#  9   VendorNo        40000 non-null  int64
#  10  VendorName      40000 non-null  object
#  11  year            40000 non-null  int32
#  12  month           40000 non-null  int32
#  13  day             40000 non-null  int32
# dtypes: float64(3), int32(3), int64(6), object(2)
# memory usage: 4.1+ MB

# %% [markdown]
# ### Applying One-Hot Encoding

# %%
description_dummies = pd.get_dummies(df_cleaned['Description'])
vendorname_dummies = pd.get_dummies(df_cleaned['VendorName'])
dfx = pd.concat([df_cleaned, description_dummies, vendorname_dummies], axis=1)
dfx.drop(['Description', 'VendorName'], axis=1, inplace=True)
dfx.head()
# Out:
#         Store  Brand  SalesQuantity  SalesDollars  SalesPrice  Volume  \
# 280017     34  25339              1         34.99       34.99     750
# 976274     11  26949              2         45.98       22.99     750
# 59970      13   5401              1          5.99        5.99     200
# 815281     73  36989              1         13.99       13.99     750
# 707907     67   8218              1         31.99       31.99    1750
#
#         Classification  ExciseTax  VendorNo  year  ...  VINEXTRA INC  \
# 280017               2       0.11      4425  2016  ...         False
# 976274               2       0.22      1128  2016  ...         False
# 59970                1       0.21      3089  2016  ...         False
# 815281               2       0.11     10754  2016  ...         False
# 707907               1       1.84      3252  2016  ...         False
#
#         VINEYARD BRANDS INC  VINILANDIA USA  VRANKEN AMERICA  \
# 280017                False           False            False
# 976274                False           False            False
# 59970                 False           False            False
# 815281                False           False            False
# 707907                False           False            False
#
#         WALPOLE MTN VIEW WINERY  WEIN BAUER INC  WESTERN SPIRITS BEVERAGE CO  \
# 280017                    False           False                        False
# 976274                    False           False                        False
# 59970                     False           False                        False
# 815281                    False           False                        False
# 707907                    False           False                        False
#
#         WILLIAM GRANT & SONS INC  WINE GROUP INC  ZORVINO VINEYARDS
# 280017                     False           False              False
# 976274                     False           False              False
# 59970                      False           False              False
# 815281                     False           False              False
# 707907                     False           False              False
#
# [5 rows x 3798 columns]

# %%
dfx
# Out:
#         Store  Brand  SalesQuantity  SalesDollars  SalesPrice  Volume  \
# 280017     34  25339              1         34.99       34.99     750
# 976274     11  26949              2         45.98       22.99     750
# 59970      13   5401              1          5.99        5.99     200
# 815281     73  36989              1         13.99       13.99     750
# 707907     67   8218              1         31.99       31.99    1750
# ...       ...    ...            ...           ...         ...     ...
# 603811     60   5735              1         12.99       12.99     750
# 861252     76  22566              1         13.99       13.99     750
# 279641     34  24863              2         47.98       23.99     750
# 591585     60  23870              1          8.99        8.99     750
# 6999        1  32675              1         10.99       10.99     750
#
#         Classification  ExciseTax  VendorNo  year  ...  VINEXTRA INC  \
# 280017               2       0.11      4425  2016  ...         False
# 976274               2       0.22      1128  2016  ...         False
# 59970                1       0.21      3089  2016  ...         False
# 815281               2       0.11     10754  2016  ...         False
# 707907               1       1.84      3252  2016  ...         False
# ...                ...        ...       ...   ...  ...           ...
# 603811               1       0.79     17035  2016  ...         False
# 861252               2       0.11     90032  2016  ...         False
# 279641               2       0.22      4425  2016  ...         False
# 591585               2       0.11       516  2016  ...         False
# 6999                 2       0.11      1392  2016  ...         False
#
#         VINEYARD BRANDS INC  VINILANDIA USA  VRANKEN AMERICA  \
# 280017                False           False            False
# 976274                False           False            False
# 59970                 False           False            False
# 815281                False           False            False
# 707907                False           False            False
# ...                     ...             ...              ...
# 603811                False           False            False
# 861252                False           False            False
# 279641                False           False            False
# 591585                False           False            False
# 6999                  False           False            False
#
#         WALPOLE MTN VIEW WINERY  WEIN BAUER INC  WESTERN SPIRITS BEVERAGE CO  \
# 280017                    False           False                        False
# 976274                    False           False                        False
# 59970                     False           False                        False
# 815281                    False           False                        False
# 707907                    False           False                        False
# ...                         ...             ...                          ...
# 603811                    False           False                        False
# 861252                    False           False                        False
# 279641                    False           False                        False
# 591585                    False           False                        False
# 6999                      False           False                        False
#
#         WILLIAM GRANT & SONS INC  WINE GROUP INC  ZORVINO VINEYARDS
# 280017                     False           False              False
# 976274                     False           False              False
# 59970                      False           False              False
# 815281                     False           False              False
# 707907                     False           False              False
# ...                          ...             ...                ...
# 603811                     False           False              False
# 861252                     False           False              False
# 279641                     False           False              False
# 591585                     False           False              False
# 6999                       False           False              False
#
# [37698 rows x 3798 columns]

# %% [markdown]
# ### Applying Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dfx.loc[:, "SalesDollars"] = scaler.fit_transform(df_cleaned[["SalesDollars"]].values.reshape(-1, 1))
dfx.loc[:, "SalesPrice"] = scaler.fit_transform(df_cleaned[["SalesPrice"]].values.reshape(-1, 1))

# %%
dfx
# Out:
#         Store  Brand  SalesQuantity  SalesDollars  SalesPrice  Volume  \
# 280017     34  25339              1      0.118512    0.641509     750
# 976274     11  26949              2      0.156820    0.415094     750
# 59970      13   5401              1      0.017428    0.094340     200
# 815281     73  36989              1      0.045314    0.245283     750
# 707907     67   8218              1      0.108055    0.584906    1750
# ...       ...    ...            ...           ...         ...     ...
# 603811     60   5735              1      0.041828    0.226415     750
# 861252     76  22566              1      0.045314    0.245283     750
# 279641     34  24863              2      0.163791    0.433962     750
# 591585     60  23870              1      0.027885    0.150943     750
# 6999        1  32675              1      0.034857    0.188679     750
#
#         Classification  ExciseTax  VendorNo  year  ...  VINEXTRA INC  \
# 280017               2       0.11      4425  2016  ...         False
# 976274               2       0.22      1128  2016  ...         False
# 59970                1       0.21      3089  2016  ...         False
# 815281               2       0.11     10754  2016  ...         False
# 707907               1       1.84      3252  2016  ...         False
# ...                ...        ...       ...   ...  ...           ...
# 603811               1       0.79     17035  2016  ...         False
# 861252               2       0.11     90032  2016  ...         False
# 279641               2       0.22      4425  2016  ...         False
# 591585               2       0.11       516  2016  ...         False
# 6999                 2       0.11      1392  2016  ...         False
#
#         VINEYARD BRANDS INC  VINILANDIA USA  VRANKEN AMERICA  \
# 280017                False           False            False
# 976274                False           False            False
# 59970                 False           False            False
# 815281                False           False            False
# 707907                False           False            False
# ...                     ...             ...              ...
# 603811                False           False            False
# 861252                False           False            False
# 279641                False           False            False
# 591585                False           False            False
# 6999                  False           False            False
#
#         WALPOLE MTN VIEW WINERY  WEIN BAUER INC  WESTERN SPIRITS BEVERAGE CO  \
# 280017                    False           False                        False
# 976274                    False           False                        False
# 59970                     False           False                        False
# 815281                    False           False                        False
# 707907                    False           False                        False
# ...                         ...             ...                          ...
# 603811                    False           False                        False
# 861252                    False           False                        False
# 279641                    False           False                        False
# 591585                    False           False                        False
# 6999                      False           False                        False
#
#         WILLIAM GRANT & SONS INC  WINE GROUP INC  ZORVINO VINEYARDS
# 280017                     False           False              False
# 976274                     False           False              False
# 59970                      False           False              False
# 815281                     False           False              False
# 707907                     False           False              False
# ...                          ...             ...                ...
# 603811                     False           False              False
# 861252                     False           False              False
# 279641                     False           False              False
# 591585                     False           False              False
# 6999                       False           False              False
#
# [37698 rows x 3798 columns]

# %% [markdown]
# ## PREDICTING SALES DEMAND

# %%
y=dfx['SalesQuantity']
x=dfx.drop(['SalesQuantity'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.9248806366047745

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def get_loc_index(VendorName, Description):
    loc_index = np.where((df['VendorName'] == VendorName) & (df['Description'] == Description))[0]
    
    # If index exists, return the first index (assuming unique matches), else return -1
    if len(loc_index) > 0:
        return loc_index[0]
    else:
        return -1

# %%
def predict_sales_quantity(VendorName, Description, Store, Brand, Volume, SalesDollars, SalesPrice, Classification, ExciseTax, VendorNo,year,month,day):
    X = np.zeros(len(x.columns))
    X[0] = Store
    X[1] = Brand
    X[2] = Volume
    X[3] = SalesDollars
    X[4] = SalesPrice
    X[5] = Classification
    X[6] = ExciseTax
    X[7] = VendorNo
    X[8] = year
    X[9] = month
    X[10]= day

    # Set the index corresponding to VendorName and Description to 1 if loc_index >= 0
    loc_index = get_loc_index(VendorName, Description)  # Assuming you have a function to get loc_index
    if loc_index >= 0:
        X[loc_index] = 1

    # Make prediction
    predicted_sales_quantity = model.predict([X])[0]  # Assuming lr is your trained model

    return predicted_sales_quantity

# %%
predict_sales_quantity('ULTRA BEVERAGE COMPANY LLP','Cecchi Sangiovese',1,18013,750,34.95,6.99,2,0.56,9165,2017,1,21)
# Out:
# 2
